# %% [markdown]
# # Hands-on TF.2: Linear Regression in TensorFlow
#
# Cas d'estudi d'una regressió lineal: y = 0.1 x + 0.3
#
# ## Crear dades en un espai bidimensional
#
# Utilitzar el programa per crear els punts dins l'espai

# %%
import numpy as np
num_puntos = 100
conjunto_puntos = []
for i in range(num_puntos):
    x1= np.random.normal(0.0, 0.55)
    y1= x1 * 0.1 + 0.3 + np.random.normal(0.0, 0.03)
    conjunto_puntos.append([x1, y1])
x_data = [v[0] for v in conjunto_puntos]
y_data = [v[1] for v in conjunto_puntos]

# %%
import matplotlib.pyplot as plt
plt.plot(x_data, y_data, 'ro', label='Original data')
plt.legend()
plt.show()

# %% [markdown]
# ## Utilitzar TensorFlow per buscar la línia que més s'aproxima als punts
#
# Utilitzar l'API de Python pel Machine Learning

# %%
import tensorflow as tf
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

# %% [markdown]
# Definir la funció de cost

# %%
loss = tf.reduce_mean(tf.square(y - y_data))
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

# %% [markdown]
# TensorFlow carrega el gràfic i executa les operacions en bucle

# %%
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)
for step in range(8):
    sess.run(train)
    ww = sess.run(W)
    bb = sess.run(b)
    print(step, ww, bb)
    plt.plot(x_data, y_data, 'ro', label='Original data')
    x_data_line = [-1.0,1.5]
    y_data_line = ww*x_data_line+bb
    plt.plot(x_data_line, y_data_line)
    plt.legend()
    plt.show()
# Out:
# (0, array([-0.4296149], dtype=float32), array([ 0.29031527], dtype=float32))
# (1, array([-0.23750225], dtype=float32), array([ 0.29459956], dtype=float32))
# (2, array([-0.11613587], dtype=float32), array([ 0.29736495], dtype=float32))
# (3, array([-0.0394623], dtype=float32), array([ 0.29911196], dtype=float32))
# (4, array([ 0.00897645], dtype=float32), array([ 0.30021566], dtype=float32))
# (5, array([ 0.03957777], dtype=float32), array([ 0.30091292], dtype=float32))
# (6, array([ 0.05891024], dtype=float32), array([ 0.30135339], dtype=float32))
# (7, array([ 0.07112359], dtype=float32), array([ 0.30163169], dtype=float32))
